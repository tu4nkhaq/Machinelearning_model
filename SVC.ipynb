# %% [markdown]
# I. Sử dụng thư viện Sklearn
# Thực hiện các yêu cầu sau với các bài tập 1, 2, 3.
# * 1) Sử dụng thuật toán Support Vector Machine để xây dựng mô hình phân lớp.
# * 2) Sử dụng tập X_test, y_test để đánh giá chất lượng của mô hình trong câu 1 bằng các
# độ đo Accuracy, Precision, Recall, F1.
# * Bài 1. Cho tập dữ liệu trong file winedata.csv. Đọc tập dữ liệu này thành các tập (X_train,
# y_train), (X_test, y_test) với tỉ lệ train_data: test_data là 80:20. Tập mẫu (X_) bao gồm:
# Alcolhol, Malic acid, Ash, Alcalinity of ash, Magnesium, Total phenols, Flavanoids,
# Nonflavanoid phenols, Proanthocyanins, Color intensity, Hue, OD280/OD315 of diluted
# wines, Prolin; tập nhãn (y_): là cột class.
# * Bài 2. Cho tập dữ liệu trong file cars.csv. Đọc tập dữ liệu này thành các tập (X_train, y_train),
# (X_test, y_test) với tỉ lệ train_data: test_data là 70:30. Tập mẫu (X_) bao gồm: buying, maint,
# doors, persons, lug_boot, safety; tập nhãn (y_): là cột acceptability. Sử dụng modul
# LabelEncoder của Sklearn để mã hóa dữ liệu trong tập mẫu (X_train) theo từng cột. Sau đó,
# sử dụng mã hóa này để mã hóa X_test theo cùng kiểu mã hóa của X_train. Ví dụ, trong
# X_train, “vhigh” được mã hóa là 0 và “high” mã hóa là 1 thì trong X_test, “vhigh” cũng được
# mã hóa là 0 và “high” được mã hóa là 1.
# * Bài 3. Cho tập dữ liệu trong file bankmarketing.csv. Đọc tập dữ liệu này thành các tập
# (X_train, y_train), (X_test, y_test) với tỉ lệ train_data: test_data là 80:20. Tập mẫu (X_) bao
# gồm: age, marital, education, housing, duration; tập nhãn (y_): là cột bankrupt. Sử dụng
# modul LabelEncoder của Sklearn để mã hóa dữ liệu trong tập mẫu (X_train) theo từng cột.
# Sau đó, sử dụng mã hóa này để mã hóa X_test theo cùng kiểu mã hóa của X_train. Ví dụ,
# trong X_train, “married” được mã hóa là 0 và “single” mã hóa là 1 thì trong X_test, “married”
# cũng được mã hóa là 0 và “single” được mã hóa là 1.
# * II.Code phương pháp Support Vector Machine
# * 1) Viết hàm fit để huấn luyện mô hình (tính w, b)
# * 2) Viết hàm predict để dự đoán nhãn của tập mẫu mới (dự đoán nhãn của tập X_tesst)
# Có thể viết 2 hàm fit và predict trong 1 class.
# * 3) Dùng hàm fit và predict (hoặc class) để thực hiện các yêu cầu trong mục I.

# %% [markdown]
# Bài 1

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/winedata.csv')

le=preprocessing.LabelEncoder()
df=df.apply(le.fit_transform)

dt_Train, dt_Test = train_test_split(df, test_size=0.2 , shuffle = True)

X_train = dt_Train.drop(['Class'],axis=1)
y_train = dt_Train['Class']
X_test = dt_Test.drop(['Class'],axis=1)
y_test = dt_Test['Class']

svc = SVC(kernel = 'linear')
svc.fit(X_train, y_train)
y_predict = svc.predict(X_test)
y_predict=np.array(y_predict)
y_test=np.array(y_test)
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict,average="macro"))
print("Recall: ", recall_score(y_test, y_predict,average="macro"))
print("F1: ", f1_score(y_test, y_predict,average="macro"))
# Out:
# Accuracy:  0.7804878048780488
# Precision:  0.7714285714285714
# Recall:  0.8074074074074074
# F1:  0.7770451770451771

# %% [markdown]
# bài 2

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/cars_chu.csv",usecols=['buying','maint','doors','persons','lug_boot','safety','acceptability'])

# Split the data into training and testing sets
dt_Train, dt_Test = train_test_split(data, test_size=0.3, shuffle=True)

X_train = dt_Train.drop(['acceptability'],axis=1)
y_train = dt_Train['acceptability']
X_test = dt_Test.drop(['acceptability'],axis=1)
y_test = dt_Test['acceptability']

encoders = {}
for col in X_train.columns:
    encoders[col]=LabelEncoder()
    X_train[col] = encoders[col].fit_transform(X_train[col])

print(X_train.head())
pla = SVC()
pla.fit(X_train, y_train)
for col in X_test.columns:
    X_test[col] = encoders[col].transform(X_test[col])

print(X_test.head())

y_predict = pla.predict(X_test)

# Evaluation
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict,average="macro"))
print("Recall: ", recall_score(y_test, y_predict,average="macro"))
print("F1: ", f1_score(y_test, y_predict,average="macro"))
# Out:
#      buying  maint  doors  persons  lug_boot  safety
# 420       1      1      3        1         0       1
# 528       0      3      3        1         0       1
# 201       1      0      3        1         1       1
# 277       1      2      2        0         0       2
# 357       1      1      1        0         0       1
#      buying  maint  doors  persons  lug_boot  safety
# 190       1      0      3        0         2       2
# 306       1      2      3        1         2       1
# 167       1      0      2        0         1       0
# 108       1      0      0        0         2       1
# 355       1      1      1        0         1       2
# Accuracy:  0.8742138364779874
# Precision:  0.8171768707482994
# Recall:  0.6617987275882012
# F1:  0.7011278195488722

# %% [markdown]
# bai3

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/bankmarketing.csv",usecols=['age', 'marital', 'education', 'housing', 'duration','bankrupt'])

# Split the data into training and testing sets
dt_Train, dt_Test = train_test_split(data, test_size=0.2, shuffle=True)

X_train = dt_Train.drop(['bankrupt'],axis=1)
y_train = dt_Train['bankrupt']
X_test = dt_Test.drop(['bankrupt'],axis=1)
y_test = dt_Test['bankrupt']
label=['marital','education','housing']
encoders = {}
for i in label:
    encoders[i]=LabelEncoder()
    X_train[i] = encoders[i].fit_transform(X_train[i])

print(X_train.head())
pla = SVC()
pla.fit(X_train, y_train)
for i in label:
    X_test[i] = encoders[i].transform(X_test[i])

print(X_test.head())

y_predict = pla.predict(X_test)

# Evaluation
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict,average="macro"))
print("Recall: ", recall_score(y_test, y_predict,average="macro"))
print("F1: ", f1_score(y_test, y_predict,average="macro"))
# Out:
#      age  marital  education  housing  duration
# 56    45        1          3        1       787
# 4     56        1          3        0       307
# 198   33        1          3        0       146
# 78    42        1          2        0       208
# 84    41        1          1        0       529
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_encode.py in _encode(values, uniques, check_unknown)
#     223         try:
# --> 224             return _map_to_integer(values, uniques)
#     225         except KeyError as e:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_encode.py in _map_to_integer(values, uniques)
#     163     table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 164     return np.array([table[v] for v in values])
#     165
#
# ...

# %% [markdown]
# II

# %% [markdown]
# 1

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn import preprocessing
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/winedata.csv')
class SVC:
    def __init__(self, learning_rate=0.01, max_inter=100, C=1.0):
        self.learning_rate = learning_rate
        self.max_inter = max_inter
        self.C = C
        self.weights = None
        self.bias = None
    def biasTrick(self,X):
        num_rows_X_test= X.shape[0]
        new_array_X_test = np.ones((num_rows_X_test, 1))
        X= np.hstack([new_array_X_test.reshape(-1,1),X])
        return X
    def fit(self, X, y):
        X= np.array(self.biasTrick(X))
        num_samples, num_features = X.shape
        self.weights = np.zeros(num_features)
        self.bias = 0

        for turn in range(self.max_inter):
            for i in range(num_samples):
                condition = 1- y[i] * (np.dot(X[i], self.weights) + self.bias) <= 0
                if condition:
                    self.weights += self.learning_rate * (X[i] * y[i])
                    self.bias += self.learning_rate * y[i]
                else:
                    self.weights -= self.learning_rate * (2 * 1 / self.max_inter * self.weights - X[i] * y[i])
                    self.bias -= self.learning_rate * y[i]

        # Apply regularization to the weights
        return self.weights, self.bias

    def predict(self, X):
        X= np.array(self.biasTrick(X))
        linear_output = np.dot(X, self.weights)+ self.bias
        predictions = np.where(linear_output > 0, 1, 0)
        return predictions
le=preprocessing.LabelEncoder()
df=df.apply(le.fit_transform)

dt_Train, dt_Test = train_test_split(df, test_size=0.2 , shuffle = True)

X_train = dt_Train.drop(['Class'],axis=1)
y_train = dt_Train['Class']
X_test = dt_Test.drop(['Class'],axis=1)
y_test = dt_Test['Class']

svc = SVC()
svc.fit(X_train, y_train)
y_predict = svc.predict(X_test)
y_predict=np.array(y_predict)
y_test=np.array(y_test)
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict,average="macro"))
print("Recall: ", recall_score(y_test, y_predict,average="macro"))
print("F1: ", f1_score(y_test, y_predict,average="macro"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/cars_chu.csv",usecols=['buying','maint','doors','persons','lug_boot','safety','acceptability'])
class SVC:
    def __init__(self, learning_rate=0.01, max_inter=100, C=1.0):
        self.learning_rate = learning_rate
        self.max_inter = max_inter
        self.C = C
        self.weights = None
        self.bias = None
    def biasTrick(self,X):
        num_rows_X_test= X.shape[0]
        new_array_X_test = np.ones((num_rows_X_test, 1))
        X= np.hstack([new_array_X_test.reshape(-1,1),X])
        return X
    def fit(self, X, y):
        X= np.array(self.biasTrick(X))
        num_samples, num_features = X.shape
        self.weights = np.zeros(num_features)
        self.bias = 0

        for turn in range(self.max_inter):
            for i in range(num_samples):
                condition = 1- y[i] * (np.dot(X[i], self.weights) + self.bias) <= 0
                if condition:
                    self.weights += self.learning_rate * (X[i] * y[i])
                    self.bias += self.learning_rate * y[i]
                else:
                    self.weights -= self.learning_rate * (2 * 1 / self.max_inter * self.weights - X[i] * y[i])
                    self.bias -= self.learning_rate * y[i]

        # Apply regularization to the weights
        return self.weights, self.bias

    def predict(self, X):
        X= np.array(self.biasTrick(X))
        linear_output = np.dot(X, self.weights)+ self.bias
        predictions = np.where(linear_output > 0, 1, 0)
        return predictions
# Split the data into training and testing sets
dt_Train, dt_Test = train_test_split(data, test_size=0.3, shuffle=True)

X_train = dt_Train.drop(['acceptability'],axis=1)
y_train = dt_Train['acceptability']
X_test = dt_Test.drop(['acceptability'],axis=1)
y_test = dt_Test['acceptability']

encoders = {}
for col in X_train.columns:
    encoders[col]=LabelEncoder()
    X_train[col] = encoders[col].fit_transform(X_train[col])

print(X_train.head())
pla = SVC()
pla.fit(X_train, y_train)
for col in X_test.columns:
    X_test[col] = encoders[col].transform(X_test[col])

print(X_test.head())

y_predict = pla.predict(X_test)

# Evaluation
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict,average="macro"))
print("Recall: ", recall_score(y_test, y_predict,average="macro"))
print("F1: ", f1_score(y_test, y_predict,average="macro"))
# Out:
#      buying  maint  doors  persons  lug_boot  safety
# 11        1      3      0        1         2       0
# 396       1      1      2        2         2       1
# 85        1      3      3        0         1       2
# 245       1      2      1        0         2       0
# 200       1      0      3        1         2       0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-98b6affd5854> in <cell line: 59>()
#      57 print(X_train.head())
#      58 pla = SVC()
# ---> 59 pla.fit(X_train, y_train)
#      60 for col in X_test.columns:
#      61     X_test[col] = encoders[col].transform(X_test[col])
#
# <ipython-input-1-98b6affd5854> in fit(self, X, y)
#      26         for turn in range(self.max_inter):
#      27             for i in range(num_samples):
# ---> 28                 condition = 1- y[i] * (np.dot(X[i], self.weights) + self.bias) <= 0
# ...

# %% [markdown]
# 3

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/bankmarketing.csv",usecols=['age', 'marital', 'education', 'housing', 'duration','bankrupt'])

class SVC:
    def __init__(self, learning_rate=0.01, max_inter=100, C=1.0):
        self.learning_rate = learning_rate
        self.max_inter = max_inter
        self.C = C
        self.weights = None
        self.bias = None
    def biasTrick(self,X):
        num_rows_X_test= X.shape[0]
        new_array_X_test = np.ones((num_rows_X_test, 1))
        X= np.hstack([new_array_X_test.reshape(-1,1),X])
        return X
    def fit(self, X, y):
        X= np.array(self.biasTrick(X))
        num_samples, num_features = X.shape
        self.weights = np.zeros(num_features)
        self.bias = 0

        for turn in range(self.max_inter):
            for i in range(num_samples):
                condition = 1- y[i] * (np.dot(X[i], self.weights) + self.bias) <= 0
                if condition:
                    self.weights += self.learning_rate * (X[i] * y[i])
                    self.bias += self.learning_rate * y[i]
                else:
                    self.weights -= self.learning_rate * (2 * 1 / self.max_inter * self.weights - X[i] * y[i])
                    self.bias -= self.learning_rate * y[i]

        # Apply regularization to the weights
        return self.weights, self.bias

    def predict(self, X):
        X= np.array(self.biasTrick(X))
        linear_output = np.dot(X, self.weights)+ self.bias
        predictions = np.where(linear_output > 0, 1, 0)
        return predictions
# Split the data into training and testing sets
dt_Train, dt_Test = train_test_split(data, test_size=0.2, shuffle=True)

X_train = dt_Train.drop(['bankrupt'],axis=1)
y_train = dt_Train['bankrupt']
X_test = dt_Test.drop(['bankrupt'],axis=1)
y_test = dt_Test['bankrupt']
label=['marital','education','housing']
encoders = {}
for i in label:
    encoders[i]=LabelEncoder()
    X_train[i] = encoders[i].fit_transform(X_train[i])

print(X_train.head())
pla = SVC()
pla.fit(X_train, y_train)
for i in label:
    X_test[i] = encoders[i].transform(X_test[i])

print(X_test.head())

y_predict = pla.predict(X_test)

# Evaluation
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict,average="macro"))
print("Recall: ", recall_score(y_test, y_predict,average="macro"))
print("F1: ", f1_score(y_test, y_predict,average="macro"))
