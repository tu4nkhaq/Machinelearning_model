# %% [markdown]
# work

# %% [markdown]
# cars chữ

# %%
import numpy as np
import pandas as pd

from sklearn.svm import SVC
from sklearn import decomposition
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/cars_chu.csv')
X_data = np.array(df[['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'acceptability']].values)

def data_encoder(X):
    for i, j in enumerate(X):
        for k in range(0, len(X[0])):
            if (j[k] == "vhigh"):
                j[k] = 0
            elif (j[k] == "high"):
                j[k] = 1
            elif (j[k] == "med"):
                j[k] = 2
            elif (j[k] == "low"):
                j[k] = 3
            elif (j[k] == "2"):
                j[k] = 4
            elif (j[k] == "3"):
                j[k] = 5
            elif (j[k] == "4"):
                j[k] = 6
            elif (j[k] == "5more"):
                j[k] = 7
            elif (j[k] == "more"):
                j[k] = 8
            elif (j[k] == "small"):
                j[k] = 9
            elif (j[k] == "big"):
                j[k] = 10
            # elif (j[k] == "acc"):
            #    j[k] = 1
            # elif (j[k] == "unacc"):
            #    j[k] = -1
    return X
data=data_encoder(X_data)

dt_Train, dt_Test = train_test_split(data, test_size=0.3 , shuffle = True)
print(dt_Train)

X_train = dt_Train[:, :6]
y_train = dt_Train[:, 6]
X_test = dt_Test[:, :6]
y_test = dt_Test[:, 6]

pla = Perceptron()
pla.fit(X_train, y_train)
y_predict = pla.predict(X_test)
count = 0
for i in range(0,len(y_predict)):
    if(y_test[i] == y_predict[i]):
        count = count +1

print('Ty le du doan dung: ', count/len(y_predict))
# Out:
# [[0 3 5 ... 10 1 'acc']
#  [1 0 6 ... 10 3 'unacc']
#  [0 1 6 ... 10 1 'unacc']
#  ...
#  [0 3 4 ... 10 1 'acc']
#  [0 3 6 ... 2 2 'acc']
#  [0 3 6 ... 9 2 'unacc']]
# Ty le du doan dung:  0.9245283018867925

# %%
import numpy as np
import pandas as pd

from sklearn.svm import SVC
from sklearn import decomposition
from sklearn.model_selection import train_test_split

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/cars_chu.csv')
X_data = np.array(df[['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'acceptability']].values)

def data_encoder(X):
    for i, j in enumerate(X):
        for k in range(0, len(X[0])):
            if (j[k] == "vhigh"):
                j[k] = 0
            elif (j[k] == "high"):
                j[k] = 1
            elif (j[k] == "med"):
                j[k] = 2
            elif (j[k] == "low"):
                j[k] = 3
            elif (j[k] == "2"):
                j[k] = 4
            elif (j[k] == "3"):
                j[k] = 5
            elif (j[k] == "4"):
                j[k] = 6
            elif (j[k] == "5more"):
                j[k] = 7
            elif (j[k] == "more"):
                j[k] = 8
            elif (j[k] == "small"):
                j[k] = 9
            elif (j[k] == "big"):
                j[k] = 10
            # elif (j[k] == "acc"):
            #    j[k] = 1
            # elif (j[k] == "unacc"):
            #    j[k] = -1
    return X
data=data_encoder(X_data)

dt_Train, dt_Test = train_test_split(data, test_size=0.3 , shuffle = True)
print(dt_Train)

X_train = dt_Train[:, :6]
y_train = dt_Train[:, 6]
X_test = dt_Test[:, :6]
y_test = dt_Test[:, 6]

pla = SVC(kernel = 'linear')
pla.fit(X_train, y_train)
y_predict = pla.predict(X_test)
count = 0
for i in range(0,len(y_predict)):
    if(y_test[i] == y_predict[i]):
        count = count +1

print('Ty le du doan dung: ', count/len(y_predict))

# %% [markdown]
# label

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron
from sklearn import preprocessing
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/cars_chu.csv')

le=preprocessing.LabelEncoder()
df=df.apply(le.fit_transform)

dt_Train, dt_Test = train_test_split(df, test_size=0.3 , shuffle = True)

X_train = dt_Train.drop(['acceptability'],axis=1)
y_train = dt_Train['acceptability']
X_test = dt_Test.drop(['acceptability'],axis=1)
y_test = dt_Test['acceptability']

pla = Perceptron()
pla.fit(X_train, y_train)
y_predict = pla.predict(X_test)
y_predict=np.array(y_predict)
y_test=np.array(y_test)
count = 0
for i in range(0,len(y_predict)):
    if(y_test[i] == y_predict[i]):
        count = count +1

print('Ty le du doan dung: ', count/len(y_predict))
# Out:
#      stt  buying  maint  doors  persons  lug_boot  safety  acceptability
# 55    55       1      3      2        0         2       2              1
# 97    97       1      3      3        1         0       2              1
# 88    88       1      3      3        0         0       2              1
# 223  223       1      2      0        0         0       2              1
# 57    57       1      3      2        0         1       1              1
# ..   ...     ...    ...    ...      ...       ...     ...            ...
# 310  310       1      2      3        1         1       2              0
# 385  385       1      1      2        0         0       2              1
# 171  171       1      0      2        1         2       1              1
# 375  375       1      1      1        2         0       1              1
# 16    16       1      3      0        1         0       2              1
#
# [371 rows x 8 columns]
# Ty le du doan dung:  0.9182389937106918

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import preprocessing
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/cars_chu.csv')

le=preprocessing.LabelEncoder()
df=df.apply(le.fit_transform)

dt_Train, dt_Test = train_test_split(df, test_size=0.3 , shuffle = True)

X_train = dt_Train.drop(['acceptability'],axis=1)
y_train = dt_Train['acceptability']
X_test = dt_Test.drop(['acceptability'],axis=1)
y_test = dt_Test['acceptability']

pla = SVC(kernel = 'linear')
pla.fit(X_train, y_train)
y_predict = pla.predict(X_test)
y_predict=np.array(y_predict)
y_test=np.array(y_test)
count = 0
for i in range(0,len(y_predict)):
    if(y_test[i] == y_predict[i]):
        count = count +1

print('Ty le du doan dung: ', count/len(y_predict))

# %% [markdown]
# weather

# %%
import numpy as np
import pandas as pd

from sklearn.svm import SVC
from sklearn import decomposition
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/weather.csv')     #kiểu dữ liệu DataFrame: cấu trúc dữ liệu 2 chiều
data1 = np.array(df[['outlook', 'temperature', 'humidity', 'wind', 'play']].values) #trả về mảng 2 chiều[n,5]

#hàm chuẩn hóa dữ liệu
def data_encoder(data):
    for i, j in enumerate(data):
        for k in range(0, 5):
            if (j[k] == "sunny"):
                j[k] = 0
            elif (j[k] == "overcast"):
                j[k] = 1
            elif (j[k] == "rainy"):
                j[k] = 2
            elif (j[k] == "hot"):
                j[k] = 3
            elif (j[k] == "mild"):
                j[k] = 4
            elif (j[k] == "cool"):
                j[k] = 5
            elif (j[k] == "high"):
                j[k] = 6
            elif (j[k] == "normal"):
                j[k] = 7
            elif (j[k] == "wind"):
                j[k] = 8
            elif (j[k] == "weak"):
                j[k] = 9
            elif (j[k] == "strong"):
                j[k] = 10
            #elif (j[k] == "no"):
             #   j[k] = 11
            #elif (j[k] == "yes"):
             #   j[k] = 12
    return data

#chuẩn hóa dữ liệu trong data1
data = data_encoder(data1)

#chia dữ liệu thành 2 phần: train 70%, test = 30%
dt_Train, dt_Test = train_test_split(data, test_size=0.3 , shuffle = True)

X_train = dt_Train[:, :4]
y_train = dt_Train[:, 4]
X_test = dt_Test[:, :4]
y_test = dt_Test[:, 4]

#perceptron: thuật toán phân lớp dữ liệu
pla = Perceptron()
pla.fit(X_train, y_train)   #sd phương thức fix trên mô hình pla để học dữ liệu

#tính giá trị dự đoán trên dữ liệu đầu vào là X_test
y_predict = pla.predict(X_test)

count = 0
print("Thực tế\t\tDự đoán")
for i in range(0,len(y_predict)):
    print(y_test[i],"\t\t", y_predict[i])
    if(y_test[i] == y_predict[i]):
        count = count +1

print('Ty le du doan dung: ', count/len(y_predict))
# Out:
# Thực tế		Dự đoán
# yes 		 yes
# yes 		 yes
# yes 		 yes
# yes 		 yes
# yes 		 yes
# Ty le du doan dung:  1.0

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


# _______________________________________________________________________________
# perceptron class

class Perceptron:
    def __init__(self, learning_rate=0.01, n_iters=1000):
        self.lr = learning_rate
        self.n_iters = n_iters
        self.activation_func = self._unit_step_func
        self.weights = None
        self.bias = None

    def fit(self, x, y):
        n_samples, n_features = x.shape
        self.weights = np.zeros(n_features)
        self.bias = 0
        y_ = np.array([1 if i > 0 else 0 for i in y])
        for _ in range(self.n_iters):
            for idx, x_i in enumerate(x):
                linear_output = np.dot(x_i, self.weights) + self.bias
                y_predicted = self.activation_func(linear_output)
                update = self.lr * (y_[idx] - y_predicted)
                self.weights += update * x_i
                self.bias += update

    def predict(self, x):
        linear_output = np.dot(x, self.weights) + self.bias
        y_predicted = self.activation_func(linear_output)
        return y_predicted

    def _unit_step_func(self, x):
        return np.where(x >= 0, 1, 0)


    def evaluate(self,y_test, y_pred):
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        return accuracy, precision, recall, f1

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/cars_chu.csv')

le=preprocessing.LabelEncoder()
df=df.apply(le.fit_transform)

dt_Train, dt_Test = train_test_split(df, test_size=0.3 , shuffle = True)

X_train = dt_Train.drop(['acceptability'],axis=1)
y_train = dt_Train['acceptability']
X_test = dt_Test.drop(['acceptability'],axis=1)
y_test = dt_Test['acceptability']

pla = Perceptron()
X_train=np.array(X_train)
y_train=np.array(y_train)
pla.fit(X_train, y_train)
y_predict = pla.predict(X_test)
y_predict=np.array(y_predict)
y_test=np.array(y_test)
count = 0
for i in range(0,len(y_predict)):
    if(y_test[i] == y_predict[i]):
        count = count +1

print('Ty le du doan dung: ', count/len(y_predict))
accuracy, precision, recall,f1=pla.evaluate(y_test,y_predict);
print(f"accuracy = {accuracy}")
print(f"precision = {precision}")

print(f"recall = {recall}")
print(f"f1 = {f1}")
# Out:
# Ty le du doan dung:  0.8679245283018868
# accuracy = 0.8679245283018868
# precision = 0.8679245283018868
# recall = 1.0
# f1 = 0.9292929292929293

# %% [markdown]
# I. Sử dụng thư viện Sklearn
# Thực hiện các yêu cầu sau với các bài tập 1, 2, 3.
# * 1) Sử dụng thuật toán Perceptron Learning Algorithm để xây dựng mô hình phân lớp.
# * 2) Sử dụng tập X_test, y_test để đánh giá chất lượng của mô hình trong câu 1 bằng các
# độ đo Accuracy, Precision, Recall, F1.
# * Bài 1. Cho tập dữ liệu trong file winedata.csv. Đọc tập dữ liệu này thành các tập (X_train,
# y_train), (X_test, y_test) với tỉ lệ train_data: test_data là 80:20. Tập mẫu (X_) bao gồm:
# Alcolhol, Malic acid, Ash, Alcalinity of ash, Magnesium, Total phenols, Flavanoids,
# Nonflavanoid phenols, Proanthocyanins, Color intensity, Hue, OD280/OD315 of diluted
# wines, Prolin; tập nhãn (y_): là cột class.
# * Bài 2. Cho tập dữ liệu trong file cars.csv. Đọc tập dữ liệu này thành các tập (X_train, y_train),
# (X_test, y_test) với tỉ lệ train_data: test_data là 70:30. Tập mẫu (X_) bao gồm: buying, maint,
# doors, persons, lug_boot, safety; tập nhãn (y_): là cột acceptability. Sử dụng modul
# LabelEncoder của Sklearn để mã hóa dữ liệu trong tập mẫu (X_train) theo từng cột. Sau đó,
# sử dụng mã hóa này để mã hóa X_test theo cùng kiểu mã hóa của X_train. Ví dụ, trong
# X_train, “vhigh” được mã hóa là 0 và “high” mã hóa là 1 thì trong X_test, “vhigh” cũng được
# mã hóa là 0 và “high” được mã hóa là 1.
# * Bài 3. Cho tập dữ liệu trong file bankmarketing.csv. Đọc tập dữ liệu này thành các tập
# (X_train, y_train), (X_test, y_test) với tỉ lệ train_data: test_data là 80:20. Tập mẫu (X_) bao
# gồm: age, marital, education, housing, duration; tập nhãn (y_): là cột bankrupt. Sử dụng
# modul LabelEncoder của Sklearn để mã hóa dữ liệu trong tập mẫu (X_train) theo từng cột.
# Sau đó, sử dụng mã hóa này để mã hóa X_test theo cùng kiểu mã hóa của X_train. Ví dụ,
# trong X_train, “married” được mã hóa là 0 và “single” mã hóa là 1 thì trong X_test, “married”
# cũng được mã hóa là 0 và “single” được mã hóa là 1.
# * II.Code phương pháp Perceptron Learning Algorithm
# * 1) Viết hàm fit để huấn luyện mô hình (tính w, b)
# * 2) Viết hàm predict để dự đoán nhãn của tập mẫu mới (dự đoán nhãn của tập X_tesst)
# Có thể viết 2 hàm fit và predict trong 1 class.
# * 3) Dùng hàm fit và predict (hoặc class) để thực hiện các yêu cầu trong mục I.

# %% [markdown]
# bai1

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn import preprocessing

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/winedata.csv')
dt_Train, dt_Test = train_test_split(df, test_size=0.2 , shuffle = True)

le=preprocessing.LabelEncoder()
df=df.apply(le.fit_transform)

dt_Train, dt_Test = train_test_split(df, test_size=0.2 , shuffle = True)

X_train = dt_Train.drop(['Class'],axis=1)
y_train = dt_Train['Class']
X_test = dt_Test.drop(['Class'],axis=1)
y_test = dt_Test['Class']

pla = Perceptron()
pla.fit(X_train, y_train)
y_predict = pla.predict(X_test)
y_predict=np.array(y_predict)
y_test=np.array(y_test)
count = 0
for i in range(0,len(y_predict)):
    if(y_test[i] == y_predict[i]):
        count = count +1

print('Ty le du doan dung: ', count/len(y_predict))
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict))
print("Recall: ", recall_score(y_test, y_predict))
print("F1: ", f1_score(y_test, y_predict))
# Out:
# Ty le du doan dung:  0.9024390243902439

# %% [markdown]
# bai2

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/cars_chu.csv",usecols=['buying','maint','doors','persons','lug_boot','safety','acceptability'])

# Split the data into training and testing sets
dt_Train, dt_Test = train_test_split(data, test_size=0.3, shuffle=True)

X_train = dt_Train.drop(['acceptability'],axis=1)
y_train = dt_Train['acceptability']
X_test = dt_Test.drop(['acceptability'],axis=1)
y_test = dt_Test['acceptability']

label=['buying','maint','doors','persons','lug_boot','safety']
encoders={}
for i in label:
    encoders[i]=LabelEncoder()
    X_train[i] = encoders[i].fit_transform(X_train[i])
pla = Perceptron()
pla.fit(X_train, y_train)

for i in label:
    X_test[i] = encoders[i].transform(X_test[i])



y_predict = pla.predict(X_test)

# Evaluation
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict,average="macro"))
print("Recall: ", recall_score(y_test, y_predict,average="macro"))
print("F1: ", f1_score(y_test, y_predict,average="macro"))
# Out:
# Accuracy:  0.6415094339622641
# Precision:  0.5578282828282828
# Recall:  0.6098145780051151
# F1:  0.5353499102794155

# %% [markdown]
# bai3

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/bankmarketing.csv",usecols=['age', 'marital', 'education', 'housing', 'duration','bankrupt'])

# Split the data into training and testing sets
dt_Train, dt_Test = train_test_split(data, test_size=0.2, shuffle=True)

X_train = dt_Train.drop(['bankrupt'],axis=1)
y_train = dt_Train['bankrupt']
X_test = dt_Test.drop(['bankrupt'],axis=1)
y_test = dt_Test['bankrupt']

le = preprocessing.LabelEncoder()
for col in X_train.columns:
    X_train[col] = le.fit_transform(X_train[col])

print(X_train.head())
pla = Perceptron()
pla.fit(X_train, y_train)
for col in X_train.columns:
    X_test[col] = le.fit_transform(X_test[col])

print(X_test.head())

y_predict = pla.predict(X_test)

# Evaluation
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict,average="macro"))
print("Recall: ", recall_score(y_test, y_predict,average="macro"))
print("F1: ", f1_score(y_test, y_predict,average="macro"))
# Out:
#      age  marital  education  housing  duration
# 207    9        2          5        1        96
# 66     7        1          6        1       111
# 34    29        1          0        1       126
# 131   11        1          1        1       130
# 234   13        1          1        1       119
#      age  marital  education  housing  duration
# 229    7        1          5        0        17
# 113    6        1          3        0        34
# 109   26        1          0        0        48
# 256    4        1          2        1        32
# 254    9        1          2        0        42
# Accuracy:  0.5
# Precision:  0.5595238095238095
# Recall:  0.5420757363253856
# F1:  0.47835420393559924

# %% [markdown]
# II

# %% [markdown]
# bai1

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn import preprocessing

class Perceptron:
    def __init__(self, learning_rate=1, n_iterations=1000):
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations
        self.weights = None
        self.bias = None

    def biasTrick(self,X):
        num_rows_X_test= X.shape[0]
        new_array_X_test = np.ones((num_rows_X_test, 1))
        X= np.hstack([new_array_X_test.reshape(-1,1),X])
        return X

    def fit(self, X, y):
        X= np.array(self.biasTrick(X))
        y = np.where(y == 1,1,-1)
        y= np.array(y)
        self.bias=0
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        # self.weights = [2.,2.,-1.,-2.,-2., 3.,4.]
        for _ in range(self.n_iterations):
            check =0
            for i in range(n_samples):
                if(y[i] * X[i]@self.weights)<=0:
                # if(y[i] * X[i]@self.weights + self.bias)<=0:
                    self.weights = self.weights + self.learning_rate * y[i] * X[i]
                    # self.bias = self.bias + self.learning_rate * y[i]
                    check+=1
            if check==0:
                break
        return self.weights

    def predict(self, X):
        X= np.array(self.biasTrick(X))
        linear_output = np.dot(X, self.weights)+ self.bias
        predictions = np.where(linear_output > 0, 1, 0)
        return predictions

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/winedata.csv')
dt_Train, dt_Test = train_test_split(df, test_size=0.2 , shuffle = True)

le=preprocessing.LabelEncoder()
df=df.apply(le.fit_transform)

dt_Train, dt_Test = train_test_split(df, test_size=0.2 , shuffle = True)

X_train = dt_Train.drop(['Class'],axis=1)
y_train = dt_Train['Class']
X_test = dt_Test.drop(['Class'],axis=1)
y_test = dt_Test['Class']

pla = Perceptron()
pla.fit(X_train, y_train)
y_predict = pla.predict(X_test)
y_predict=np.array(y_predict)
y_test=np.array(y_test)
count = 0
for i in range(0,len(y_predict)):
    if(y_test[i] == y_predict[i]):
        count = count +1

print('Ty le du doan dung: ', count/len(y_predict))
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict,average="macro"))
print("Recall: ", recall_score(y_test, y_predict,average="macro"))
print("F1: ", f1_score(y_test, y_predict,average="macro"))
# Out:
# Ty le du doan dung:  0.5121951219512195
# Accuracy:  0.5121951219512195
# Precision:  0.4646464646464647
# Recall:  0.4603174603174603
# F1:  0.37231384307846077
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# bai2

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

class Perceptron:
    def __init__(self, learning_rate=1, n_iterations=1000):
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations
        self.weights = None
        self.bias = None

    def biasTrick(self,X):
        num_rows_X_test= X.shape[0]
        new_array_X_test = np.ones((num_rows_X_test, 1))
        X= np.hstack([new_array_X_test.reshape(-1,1),X])
        return X

    def fit(self, X, y):
        X= np.array(self.biasTrick(X))
        y = np.where(y == 1,1,-1)
        y= np.array(y)
        self.bias=0
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        # self.weights = [2.,2.,-1.,-2.,-2., 3.,4.]
        for _ in range(self.n_iterations):
            check =0
            for i in range(n_samples):
                if(y[i] * X[i]@self.weights)<=0:
                # if(y[i] * X[i]@self.weights + self.bias)<=0:
                    self.weights = self.weights + self.learning_rate * y[i] * X[i]
                    # self.bias = self.bias + self.learning_rate * y[i]
                    check+=1
            if check==0:
                break
        return self.weights

    def predict(self, X):
        X= np.array(self.biasTrick(X))
        linear_output = np.dot(X, self.weights)+ self.bias
        predictions = np.where(linear_output > 0, 'acc', 'unacc')
        return predictions

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/cars_chu.csv",usecols=['buying','maint','doors','persons','lug_boot','safety','acceptability'])

# Split the data into training and testing sets
dt_Train, dt_Test = train_test_split(data, test_size=0.3, shuffle=True)

X_train = dt_Train.drop(['acceptability'],axis=1)
y_train = dt_Train['acceptability']
X_test = dt_Test.drop(['acceptability'],axis=1)
y_test = dt_Test['acceptability']

label=['buying','maint','doors','persons','lug_boot','safety']
encoders={}
for i in label:
    encoders[i]=LabelEncoder()
    X_train[i] = encoders[i].fit_transform(X_train[i])

pla = Perceptron()

pla.fit(X_train, y_train)

for i in label:
    X_test[i] = encoders[i].transform(X_test[i])

y_predict = pla.predict(X_test)

# Evaluation
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict,average="macro"))
print("Recall: ", recall_score(y_test, y_predict,average="macro"))
print("F1: ", f1_score(y_test, y_predict,average="macro"))
# Out:
# Accuracy:  0.8742138364779874
# Precision:  0.4371069182389937
# Recall:  0.5
# F1:  0.4664429530201342
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# bai 3

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/bankmarketing.csv",usecols=['age', 'marital', 'education', 'housing', 'duration','bankrupt'])

# Split the data into training and testing sets
dt_Train, dt_Test = train_test_split(data, test_size=0.2, shuffle=True)

X_train = dt_Train.drop(['bankrupt'],axis=1)
y_train = dt_Train['bankrupt']
X_test = dt_Test.drop(['bankrupt'],axis=1)
y_test = dt_Test['bankrupt']

le = preprocessing.LabelEncoder()
for col in X_train.columns:
    X_train[col] = le.fit_transform(X_train[col])

print(X_train.head())
pla = Perceptron()
pla.fit(X_train, y_train)
for col in X_train.columns:
    X_test[col] = le.fit_transform(X_test[col])

print(X_test.head())

y_predict = pla.predict(X_test)

# Evaluation
print("Accuracy: ", accuracy_score(y_test, y_predict))
print("Precision: ", precision_score(y_test, y_predict,average="macro"))
print("Recall: ", recall_score(y_test, y_predict,average="macro"))
print("F1: ", f1_score(y_test, y_predict,average="macro"))
# Out:
#      age  marital  education  housing  duration
# 123   17        1          5        0       103
# 254   14        1          2        0       137
# 60    26        1          2        1       168
# 160   15        1          2        0         5
# 58     1        2          5        1        57
#      age  marital  education  housing  duration
# 182   21        1          0        0         7
# 85     9        1          5        1        22
# 45    24        1          5        1        48
# 99    17        1          0        0         0
# 51    25        1          3        0        31
# Accuracy:  0.46296296296296297
# Precision:  0.2403846153846154
# Recall:  0.46296296296296297
# F1:  0.31645569620253167
