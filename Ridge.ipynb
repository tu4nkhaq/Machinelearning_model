# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score,mean_squared_error, mean_absolute_error
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split

df = pd.read_csv('./drive/MyDrive/Colab Notebooks/USA_Housing.csv')
dt_Train, dt_Test = train_test_split(df, test_size=0.3 , shuffle = False)

Class = df.keys()[-1]

X_train = dt_Train.iloc[:,:4]
y_train = dt_Train[Class]
X_test = dt_Test.iloc[:,:4]
y_test = dt_Test[Class]
# print(y_train)
# print(X_train)
reg = Ridge(alpha=0.01)
reg.fit(X_train, y_train)

y_pred = reg.predict(X_test)
y = np.array(y_test)

print("Coefficient of determination: %.2f" % r2_score (y_test, y_pred) )

y_pred = reg.predict(X_test)
print('\n')

nse = 1 - (np.sum((y_test - y_pred)**2) / np.sum((y_test - np.mean(y_test))**2))
print("NSE: %.2f" % nse)
print('\n')

r2 = r2_score(y_test, y_pred)
print("R2: %.2f" % r2)
print('\n')

mae = mean_absolute_error(y_test, y_pred)
print("MAE: %.2f" % mae)
print('\n')

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %.2f" % rmse)
print('\n')

print("Thuc te              Du doan             Chenh lech")
for i in range(0, len(y)):
   print("%.2f" % y[i],"       ", y_pred[i], "     ", abs(y[i] -y_pred[i]))
# Out:
# Coefficient of determination: 0.66
#
#
# NSE: 0.66
#
#
# R2: 0.66
#
#
# MAE: 141801.60
#
#
# RMSE: 166094.34
#
#
# Thuc te              Du doan             Chenh lech
# 1416965.98         1512113.1738537182       95147.19485371816
# 1046721.98         1274009.215310331       227287.23931033094
# 939040.00         902369.3362850891       36670.66731491091
# 1383031.33         1554417.8806559527       171386.5486559528
# 1072503.24         1192699.0446712733       120195.80667127343
# 1134397.76         1322832.1941815172       188434.43618151732
# 734827.51         605178.2775749858       129649.23042501428
# 991892.32         952657.6465149052       39234.670985094854
# 1057252.58         1164110.2142774481       106857.63127744803
# 1237224.86         1115304.793919797       121920.06508020288
# 1442632.54         1315707.2254536124       126925.31554638757
# 1877402.32         1711413.4961901987       165988.82380980137
# 1394518.42         1475523.4760426679       81005.06104266783
# 953939.33         696202.2248776862       257737.10502231377
# 1219778.03         1488382.387230706       268604.35323070595
# 1287325.38         1471725.8943625675       184400.51236256748
# 1739893.55         1600047.8948806566       139845.66011934332
# 1213382.22         1355666.972857641       142284.74985764106
# 1007478.75         1061200.7578660347       53722.00986603473
# 1528756.13         1437414.9736220273       91341.15237797261
# 1182459.77         1314219.9680308755       131760.19603087544
# 1474546.76         1438397.7756123645       36148.98638763558
# 1078016.94         969187.2881051949       108829.65189480502
# 1453381.62         1259187.6043273755       194194.01967262453
# 1495012.97         1357219.9865983361       137792.97840166395
# 714148.41         696231.9728734675       17916.44192653254
# 894292.05         672253.3744837055       222038.67291629454
# 1159841.83         1268515.225436294       108673.39443629398
# 1195986.30         1440878.226625658       244891.927625658
# 1381430.63         1479582.105437955       98151.475437955
# 1534889.85         1381516.2026498648       153373.65035013505
# 1494125.33         1447534.141375165       46591.18862483511
# 1356146.26         1163068.5126698841       193077.7483301158
# 1454943.07         1356241.7605209695       98701.3134790305
# 774118.19         770714.1406381074       3404.047161892522
# 889113.24         708935.3793324898       180177.8595675102
# 1211102.21         1049187.7308449545       161914.4801550454
# 658646.18         913223.2263047206       254577.04160472064
# 1400104.87         1338798.496018373       61306.3749816271
# 1262017.79         1041951.7391541447       220066.05284585524
# 553077.21         589812.0616050749       36734.84900507494
# 1203247.89         1046659.6182360547       156588.27176394523
# 1115323.01         1004653.2459462243       110669.76905377558
# 1301881.42         1415864.605766897       113983.18876689719
# 1006687.39         1152130.0311414455       145442.64414144552
# 749383.07         1037748.6739996127       288365.60139961273
# 1075596.59         1215086.8893932663       139490.30239326623
# 739870.79         1051014.5523034823       311143.75870348234
# 1442945.15         1433793.9108621879       9151.234137812164
# 828497.07         1080764.955659498       252267.888559498
# 1373290.86         1370580.7992243846       2710.061775615439
# 925566.33         1029951.0106841959       104384.67938419594
# 1552536.76         1893915.9520984525       341379.1880984525
# 1335904.50         1228407.4384729606       107497.06252703932
# 960808.29         1152610.5951517536       191802.3040517536
# 1405933.02         1415712.1720009907       9779.153000990627
# 619087.69         971307.3925085617       352219.6989085617
# 1329273.23         1042104.1752893119       287169.052710688
# 1261843.84         961379.2982753529       300464.5457246471
# 1175781.42         972593.2364929942       203188.18150700582
# 1437053.56         1330885.9981844937       106167.55881550629
# 1594415.23         1601831.3637516429       7416.137751642847
# 931358.00         826802.8205701513       104555.1748298487
# 798639.65         739741.1191679551       58898.53503204486
# 1451739.62         1347095.0802080003       104644.54479199974
# 1278991.69         1188425.3035183656       90566.38548163441

# %% [markdown]
# bai 2

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score,mean_squared_error, mean_absolute_error
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split

df = pd.read_csv('./drive/MyDrive/Colab Notebooks/StudentsPerformance.csv')
dt_Train, dt_Test = train_test_split(df, test_size=0.3 , shuffle = False)

Class = df.keys()[-1]

X_train=dt_Train[['Gioi tinh', 'Dan toc', 'Trinh do hoc van cua bo me', 'Dinh duong', 'Toan ','Van']]
y_train = dt_Train[Class]
X_test = dt_Test[['Gioi tinh', 'Dan toc', 'Trinh do hoc van cua bo me', 'Dinh duong', 'Toan ','Van']]
y_test = dt_Test[Class]
# print(y_train)
# print(X_test)
reg = Ridge(alpha=0.01)
reg.fit(X_train, y_train)

y_pred = reg.predict(X_test)
y = np.array(y_test)

print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred) )

y_pred = reg.predict(X_test)
print('\n')

nse = 1 - (np.sum((y_test - y_pred)**2) / np.sum((y_test - np.mean(y_test))**2))
print("NSE: %.2f" % nse)
print('\n')

r2 = r2_score(y_test, y_pred)
print("R2: %.2f" % r2)
print('\n')

mae = mean_absolute_error(y_test, y_pred)
print("MAE: %.2f" % mae)
print('\n')

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %.2f" % rmse)
print('\n')

print("Thuc te              Du doan             Chenh lech")
for i in range(0, len(y)):
   print("%.2f" % y[i],"       ", y_pred[i], "     ", abs(y[i] -y_pred[i]))
# Out:
# Coefficient of determination: 0.93
#
#
# NSE: 0.93
#
#
# R2: 0.93
#
#
# MAE: 3.27
#
#
# RMSE: 3.95
#
#
# Thuc te              Du doan             Chenh lech
# 82.00         83.3983144536841       1.398314453684094
# 60.00         60.19053356431992       0.19053356431992086
# 67.00         75.54504304669481       8.545043046694815
# 80.00         84.19937997500696       4.199379975006963
# 100.00         99.58556567362292       0.41443432637707645
# 69.00         70.02630757215596       1.0263075721559574
# 60.00         52.79408042210256       7.20591957789744
# 61.00         63.511086900129186       2.511086900129186
# 67.00         63.05682630902627       3.9431736909737296
# 77.00         79.60855693434469       2.6085569343446906
# 60.00         58.48797707580202       1.5120229241979786
# 58.00         60.42383544612492       2.4238354461249187
# 48.00         41.850032265429626       6.1499677345703745
# 94.00         94.89524861218679       0.8952486121867906
# 23.00         22.686416298053008       0.3135837019469925
# 78.00         75.25803842895479       2.741961571045209
# 86.00         79.58742223318572       6.41257776681428
# 91.00         86.52957487018902       4.470425129810977
# 82.00         76.57497976967298       5.425020230327021
# 54.00         49.244666310885506       4.755333689114494
# 51.00         55.89637867735074       4.896378677350739
# 76.00         73.20338741255435       2.796612587445651
# 45.00         46.893325247035804       1.8933252470358042
# 83.00         83.29179247252821       0.29179247252821483
# 75.00         78.72119219570826       3.721192195708255
# 78.00         79.25730806558752       1.257308065587523
# 76.00         72.04136987995795       3.958630120042045
# 74.00         72.35560960754185       1.644390392458149
# 62.00         59.46514175423011       2.5348582457698896
# 95.00         99.21143315853776       4.2114331585377585
# 55.00         53.55469459660781       1.4453054033921902
# 65.00         69.78597459028111       4.785974590281114
# 77.00         77.83912375892645       0.8391237589264477
# 86.00         85.8182905345895       0.18170946541050625

# %% [markdown]
# bài 3

# %%
import pandas as pd
from sklearn.metrics import r2_score,mean_squared_error, mean_absolute_error
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
import numpy as np


data = pd.read_csv('./drive/MyDrive/Colab Notebooks/StudentsPerformance.csv', usecols=['Dan toc', 'Trinh do hoc van cua bo me', 'Dinh duong', 'Toan ','Van','Anh'])[['Dan toc', 'Trinh do hoc van cua bo me', 'Dinh duong', 'Van', 'Anh','Toan ']]
dt_Train, dt_Test = train_test_split(data, test_size=0.3, shuffle=False)

X_train = dt_Train.iloc[:,:6]
y_train=dt_Train.iloc[:,5]

X_test = dt_Test.iloc[:,:6]
y_test=dt_Test.iloc[:,5]

# print('X_train: ')
# print( X_train)
# print('\n')
# print('y_train: ')
# print( y_train)
# print('\n')
# print('X_test: ')
# print( X_test)
# print('\n')
# print('y_test: ' )
# print( y_test)
# print('\n')

reg = Ridge(alpha=0.01)
reg.fit(X_train, y_train)

y_pred = reg.predict(X_test)
y = np.array(y_test)

print("Coefficient of determination: %.2f" % r2_score (y_test, y_pred) )

y_pred = reg.predict(X_test)
print('\n')

nse = 1 - (np.sum((y_test - y_pred)**2) / np.sum((y_test - np.mean(y_test))**2))
print("NSE: %.2f" % nse)
print('\n')

r2 = r2_score(y_test, y_pred)
print("R2: %.2f" % r2)
print('\n')

mae = mean_absolute_error(y_test, y_pred)
print("MAE: %.2f" % mae)
print('\n')

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %.2f" % rmse)
print('\n')

print("Thuc te              Du doan             Chenh lech")
for i in range(0, len(y)):
   print("%.2f" % y[i],"       ", y_pred[i], "     ", abs(y[i] -y_pred[i]))
